# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.loadtxt("../output/coin_flips_count_leading_dist.txt")
plt.xlim(0, 10)
plt.hist(x, density=True)
# Out:
# (array([3.80535652e-01, 4.06134783e-02, 1.01900000e-02, 3.00130435e-03,
#         3.30869565e-04, 8.56521739e-05, 2.00000000e-05, 4.78260870e-06,
#         4.34782609e-07, 4.34782609e-07]),
#  array([ 0. ,  2.3,  4.6,  6.9,  9.2, 11.5, 13.8, 16.1, 18.4, 20.7, 23. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.loadtxt("../output/coin_flips_for_real_dist.txt")
plt.xlim(0, 10)
plt.hist(x, density=True)
# Out:
# (array([4.16693333e-01, 4.45385714e-02, 1.11985714e-02, 2.84428571e-03,
#         6.95238095e-04, 1.57619048e-04, 4.42857143e-05, 1.42857143e-05,
#         3.33333333e-06, 9.52380952e-07]),
#  array([ 0. ,  2.1,  4.2,  6.3,  8.4, 10.5, 12.6, 14.7, 16.8, 18.9, 21. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# coin_flip_count_leading
# Duration: 2948╬╝s (2.948ms)
#
# coin_flip_for_real
# Duration: 39591╬╝s (39.591ms)
